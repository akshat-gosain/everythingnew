# %%
import pandas as pd

# %%
bios = pd.read_csv('https://raw.githubusercontent.com/KeithGalli/Olympics-Dataset/master/athletes/bios.csv')

# %%
bios.head()
# Out:
#                                        Roles   Sex  \
# 0                  Competed in Olympic Games  Male
# 1                  Competed in Olympic Games  Male
# 2  Competed in Olympic Games • Administrator  Male
# 3                  Competed in Olympic Games  Male
# 4                  Competed in Olympic Games  Male
#
#                                            Full name              Used name  \
# 0  François Joseph Marie Antoine "Jean-François"•...  Jean-François•Blanchy
# 1                            Arnaud Benjamin•Boetsch         Arnaud•Boetsch
# 2                        Jean Laurent Robert•Borotra           Jean•Borotra
# 3               Jacques Marie Stanislas Jean•Brugnon        Jacques•Brugnon
# 4                                 Henry Albert•Canet           Albert•Canet
#
#                                                 Born  \
# 0        12 December 1886 in Bordeaux, Gironde (FRA)
# 1             1 April 1969 in Meulan, Yvelines (FRA)
# 2  13 August 1898 in Biarritz, Pyrénées-Atlantiqu...
# 3            11 May 1895 in Paris VIIIe, Paris (FRA)
# 4         17 April 1878 in Wandsworth, England (GBR)
#
#                                                 Died     NOC  athlete_id  \
# 0  2 October 1960 in Saint-Jean-de-Luz, Pyrénées-...  France           1
# 1                                                NaN  France           2
# 2  17 July 1994 in Arbonne, Pyrénées-Atlantiques ...  France           3
# 3              20 March 1978 in Monaco, Monaco (MON)  France           4
# 4            25 July 1930 in Paris VIIe, Paris (FRA)  France           5
#
#      Measurements                         Affiliations  \
# 0             NaN                                  NaN
# 1  183 cm / 76 kg   Racing Club de France, Paris (FRA)
# 2  183 cm / 76 kg                     TCP, Paris (FRA)
# 3  168 cm / 64 kg  Sporting club de Paris, Paris (FRA)
# 4             NaN                     TCP, Paris (FRA)
#
#                                 Nick/petnames Title(s) Other names  \
# 0                                         NaN      NaN         NaN
# 1                                         NaN      NaN         NaN
# 2  Le Basque Bondissant (The Bounding Basque)      NaN         NaN
# 3                                        Toto      NaN         NaN
# 4                                         NaN      NaN         NaN
#
#   Nationality Original name Name order
# 0         NaN           NaN        NaN
# 1         NaN           NaN        NaN
# 2         NaN           NaN        NaN
# 3         NaN           NaN        NaN
# 4         NaN           NaN        NaN

# %%
bios
# Out:
#                                             Roles     Sex  \
# 0                       Competed in Olympic Games    Male
# 1                       Competed in Olympic Games    Male
# 2       Competed in Olympic Games • Administrator    Male
# 3                       Competed in Olympic Games    Male
# 4                       Competed in Olympic Games    Male
# ...                                           ...     ...
# 145495                  Competed in Olympic Games  Female
# 145496                  Competed in Olympic Games  Female
# 145497                  Competed in Olympic Games  Female
# 145498                  Competed in Olympic Games    Male
# 145499                Non-starter • Administrator    Male
#
#                                                 Full name  \
# 0       François Joseph Marie Antoine "Jean-François"•...
# 1                                 Arnaud Benjamin•Boetsch
# 2                             Jean Laurent Robert•Borotra
# 3                    Jacques Marie Stanislas Jean•Brugnon
# 4                                      Henry Albert•Canet
# ...                                                   ...
# 145495                                  Polina•Luchnikova
# 145496                     Valeriya Sergeyevna•Merkusheva
# 145497                                    Yuliya•Smirnova
# 145498                                     André•Foussard
# 145499                      William Berge "Bill"•Phillips
#
#                     Used name  \
# 0       Jean-François•Blanchy
# 1              Arnaud•Boetsch
# 2                Jean•Borotra
# 3             Jacques•Brugnon
# 4                Albert•Canet
# ...                       ...
# 145495      Polina•Luchnikova
# 145496    Valeriya•Merkusheva
# 145497        Yuliya•Smirnova
# 145498         André•Foussard
# 145499          Bill•Phillips
#
#                                                      Born  \
# 0             12 December 1886 in Bordeaux, Gironde (FRA)
# 1                  1 April 1969 in Meulan, Yvelines (FRA)
# 2       13 August 1898 in Biarritz, Pyrénées-Atlantiqu...
# 3                 11 May 1895 in Paris VIIIe, Paris (FRA)
# 4              17 April 1878 in Wandsworth, England (GBR)
# ...                                                   ...
# 145495         30 January 2002 in Serov, Sverdlovsk (RUS)
# 145496  20 September 1999 in Moskva (Moscow), Moskva (...
# 145497            8 May 1998 in Kotlas, Arkhangelsk (RUS)
# 145498            19 May 1899 in Niort, Deux-Sèvres (FRA)
# 145499  15 July 1913 in Dulwich Hill, New South Wales ...
#
#                                                      Died        NOC  \
# 0       2 October 1960 in Saint-Jean-de-Luz, Pyrénées-...     France
# 1                                                     NaN     France
# 2       17 July 1994 in Arbonne, Pyrénées-Atlantiques ...     France
# 3                   20 March 1978 in Monaco, Monaco (MON)     France
# 4                 25 July 1930 in Paris VIIe, Paris (FRA)     France
# ...                                                   ...        ...
# 145495                                                NaN        ROC
# 145496                                                NaN        ROC
# 145497                                                NaN        ROC
# 145498          18 March 1986 in Niort, Deux-Sèvres (FRA)     France
# 145499   20 October 2003 in Sydney, New South Wales (AUS)  Australia
#
#         athlete_id    Measurements  \
# 0                1             NaN
# 1                2  183 cm / 76 kg
# 2                3  183 cm / 76 kg
# 3                4  168 cm / 64 kg
# 4                5             NaN
# ...            ...             ...
# 145495      149222  167 cm / 61 kg
# 145496      149223  168 cm / 65 kg
# 145497      149224  163 cm / 55 kg
# 145498      149225          166 cm
# 145499      149814             NaN
#
#                                        Affiliations  \
# 0                                               NaN
# 1                Racing Club de France, Paris (FRA)
# 2                                  TCP, Paris (FRA)
# 3               Sporting club de Paris, Paris (FRA)
# 4                                  TCP, Paris (FRA)
# ...                                             ...
# 145495                            Agidel, Ufa (RUS)
# 145496  SKIF Nizhny Novgorod, Nizhny Novgorod (RUS)
# 145497                            Agidel, Ufa (RUS)
# 145498                  Beauvoisine FC, Rouen (FRA)
# 145499                                          NaN
#
#                                      Nick/petnames Title(s) Other names  \
# 0                                              NaN      NaN         NaN
# 1                                              NaN      NaN         NaN
# 2       Le Basque Bondissant (The Bounding Basque)      NaN         NaN
# 3                                             Toto      NaN         NaN
# 4                                              NaN      NaN         NaN
# ...                                            ...      ...         ...
# 145495                                         NaN      NaN         NaN
# 145496                                         NaN      NaN         NaN
# 145497                                         NaN      NaN         NaN
# 145498                                         NaN      NaN         NaN
# 145499                                         NaN      NaN         NaN
#
#        Nationality                Original name Name order
# 0              NaN                          NaN        NaN
# 1              NaN                          NaN        NaN
# 2              NaN                          NaN        NaN
# 3              NaN                          NaN        NaN
# 4              NaN                          NaN        NaN
# ...            ...                          ...        ...
# 145495         NaN                          NaN        NaN
# 145496         NaN  Валерия Сергеевна•Меркушева        NaN
# 145497         NaN                Юлия•Смирнова        NaN
# 145498         NaN                          NaN        NaN
# 145499         NaN                          NaN        NaN
#
# [145500 rows x 16 columns]

# %% [markdown]
# ### What should we clean up?

# %% [markdown]
# - [x] Get rid of bullet points in Used Names
# - [x] Split height/weight
# - [x] Parse out dates from `Born` & `Died` column
# - [x] Parse out city, region, and country from `Born` column
# - [ ] Get rid of extra columns

# %%
df = bios.copy()

# %%
df['name'] = df['Used name'].str.replace("•", " ")

# %%
df.head()
# Out:
#                                        Roles   Sex  \
# 0                  Competed in Olympic Games  Male
# 1                  Competed in Olympic Games  Male
# 2  Competed in Olympic Games • Administrator  Male
# 3                  Competed in Olympic Games  Male
# 4                  Competed in Olympic Games  Male
#
#                                            Full name              Used name  \
# 0  François Joseph Marie Antoine "Jean-François"•...  Jean-François•Blanchy
# 1                            Arnaud Benjamin•Boetsch         Arnaud•Boetsch
# 2                        Jean Laurent Robert•Borotra           Jean•Borotra
# 3               Jacques Marie Stanislas Jean•Brugnon        Jacques•Brugnon
# 4                                 Henry Albert•Canet           Albert•Canet
#
#                                                 Born  \
# 0        12 December 1886 in Bordeaux, Gironde (FRA)
# 1             1 April 1969 in Meulan, Yvelines (FRA)
# 2  13 August 1898 in Biarritz, Pyrénées-Atlantiqu...
# 3            11 May 1895 in Paris VIIIe, Paris (FRA)
# 4         17 April 1878 in Wandsworth, England (GBR)
#
#                                                 Died     NOC  athlete_id  \
# 0  2 October 1960 in Saint-Jean-de-Luz, Pyrénées-...  France           1
# 1                                                NaN  France           2
# 2  17 July 1994 in Arbonne, Pyrénées-Atlantiques ...  France           3
# 3              20 March 1978 in Monaco, Monaco (MON)  France           4
# 4            25 July 1930 in Paris VIIe, Paris (FRA)  France           5
#
#      Measurements                         Affiliations  \
# 0             NaN                                  NaN
# 1  183 cm / 76 kg   Racing Club de France, Paris (FRA)
# 2  183 cm / 76 kg                     TCP, Paris (FRA)
# 3  168 cm / 64 kg  Sporting club de Paris, Paris (FRA)
# 4             NaN                     TCP, Paris (FRA)
#
#                                 Nick/petnames Title(s) Other names  \
# 0                                         NaN      NaN         NaN
# 1                                         NaN      NaN         NaN
# 2  Le Basque Bondissant (The Bounding Basque)      NaN         NaN
# 3                                        Toto      NaN         NaN
# 4                                         NaN      NaN         NaN
#
#   Nationality Original name Name order                   name
# 0         NaN           NaN        NaN  Jean-François Blanchy
# 1         NaN           NaN        NaN         Arnaud Boetsch
# 2         NaN           NaN        NaN           Jean Borotra
# 3         NaN           NaN        NaN        Jacques Brugnon
# 4         NaN           NaN        NaN           Albert Canet

# %%
# Split the Measurements column into height & weight columns
df[['height_cm', 'weight_kg']] = df['Measurements'].str.split('/', expand=True)

# %%
df.head()
# Out:
#                                        Roles   Sex  \
# 0                  Competed in Olympic Games  Male
# 1                  Competed in Olympic Games  Male
# 2  Competed in Olympic Games • Administrator  Male
# 3                  Competed in Olympic Games  Male
# 4                  Competed in Olympic Games  Male
#
#                                            Full name              Used name  \
# 0  François Joseph Marie Antoine "Jean-François"•...  Jean-François•Blanchy
# 1                            Arnaud Benjamin•Boetsch         Arnaud•Boetsch
# 2                        Jean Laurent Robert•Borotra           Jean•Borotra
# 3               Jacques Marie Stanislas Jean•Brugnon        Jacques•Brugnon
# 4                                 Henry Albert•Canet           Albert•Canet
#
#                                                 Born  \
# 0        12 December 1886 in Bordeaux, Gironde (FRA)
# 1             1 April 1969 in Meulan, Yvelines (FRA)
# 2  13 August 1898 in Biarritz, Pyrénées-Atlantiqu...
# 3            11 May 1895 in Paris VIIIe, Paris (FRA)
# 4         17 April 1878 in Wandsworth, England (GBR)
#
#                                                 Died     NOC  athlete_id  \
# 0  2 October 1960 in Saint-Jean-de-Luz, Pyrénées-...  France           1
# 1                                                NaN  France           2
# 2  17 July 1994 in Arbonne, Pyrénées-Atlantiques ...  France           3
# 3              20 March 1978 in Monaco, Monaco (MON)  France           4
# 4            25 July 1930 in Paris VIIe, Paris (FRA)  France           5
#
#      Measurements                         Affiliations  \
# 0             NaN                                  NaN
# 1  183 cm / 76 kg   Racing Club de France, Paris (FRA)
# 2  183 cm / 76 kg                     TCP, Paris (FRA)
# 3  168 cm / 64 kg  Sporting club de Paris, Paris (FRA)
# 4             NaN                     TCP, Paris (FRA)
#
#                                 Nick/petnames Title(s) Other names  \
# 0                                         NaN      NaN         NaN
# 1                                         NaN      NaN         NaN
# 2  Le Basque Bondissant (The Bounding Basque)      NaN         NaN
# 3                                        Toto      NaN         NaN
# 4                                         NaN      NaN         NaN
#
#   Nationality Original name Name order                   name height_cm  \
# 0         NaN           NaN        NaN  Jean-François Blanchy       NaN
# 1         NaN           NaN        NaN         Arnaud Boetsch   183 cm
# 2         NaN           NaN        NaN           Jean Borotra   183 cm
# 3         NaN           NaN        NaN        Jacques Brugnon   168 cm
# 4         NaN           NaN        NaN           Albert Canet       NaN
#
#   weight_kg
# 0       NaN
# 1     76 kg
# 2     76 kg
# 3     64 kg
# 4       NaN

# %%
# Get rid of " cm" and the " kg" from our new columns
df['height_cm'] = pd.to_numeric(df['height_cm'].str.strip(' cm'), errors='coerce')
df['weight_kg'] = pd.to_numeric(df['weight_kg'].str.strip(' kg'), errors='coerce')

# %%
df.sort_values('height_cm', ascending=False)
# Out:
#                                     Roles     Sex  \
# 89070   Competed in Olympic Games • Other    Male
# 5781            Competed in Olympic Games    Male
# 6978            Competed in Olympic Games    Male
# 89075           Competed in Olympic Games    Male
# 120266          Competed in Olympic Games    Male
# ...                                   ...     ...
# 145490          Competed in Olympic Games    Male
# 145491          Competed in Olympic Games    Male
# 145492          Competed in Olympic Games    Male
# 145493          Competed in Olympic Games  Female
# 145499        Non-starter • Administrator    Male
#
#                              Full name              Used name  \
# 89070                         Yao•Ming               Yao•Ming
# 5781     Thomas Loren "Tommy"•Burleson         Tommy•Burleson
# 6978             Arvydas Romas•Sabonis        Arvydas•Sabonis
# 89075         Roberto•Dueñas Hernández         Roberto•Dueñas
# 120266                    Zhang•Zhaoxu           Zhang•Zhaoxu
# ...                                ...                    ...
# 145490                     Sin•Ye-Chan            Sin•Ye-Chan
# 145491                   Matthew•Wepke          Matthew•Wepke
# 145492  Carlos•García-Ordóñez Montalvo  Carlos•García-Ordóñez
# 145493    Landysh Ilsurovna•Falyakhova     Landysh•Falyakhova
# 145499   William Berge "Bill"•Phillips          Bill•Phillips
#
#                                                      Born  \
# 89070   12 September 1980 in Xuhui District, Shanghai ...
# 5781    24 February 1952 in Crossnore, North Carolina ...
# 6978             19 December 1964 in Kaunas, Kaunas (LTU)
# 89075             1 November 1975 in Madrid, Madrid (ESP)
# 120266        18 November 1987 in Binzhou, Shandong (CHN)
# ...                                                   ...
# 145490                                       13 June 1995
# 145491                                    5 December 1989
# 145492  24 April 1927 in La Habana (Havana), Ciudad de...
# 145493  31 August 1998 in Dva Polya Artash, Respublika...
# 145499  15 July 1913 in Dulwich Hill, New South Wales ...
#
#                                                     Died  \
# 89070                                                NaN
# 5781                                                 NaN
# 6978                                                 NaN
# 89075                                                NaN
# 120266                                               NaN
# ...                                                  ...
# 145490                                               NaN
# 145491                                               NaN
# 145492          24 November 2019 in Miami, Florida (USA)
# 145493                                               NaN
# 145499  20 October 2003 in Sydney, New South Wales (AUS)
#
#                                NOC  athlete_id     Measurements  \
# 89070   People's Republic of China       89782  226 cm / 141 kg
# 5781                 United States        5804  223 cm / 102 kg
# 6978        Lithuania Soviet Union        7013  223 cm / 122 kg
# 89075                        Spain       89787  221 cm / 137 kg
# 120266  People's Republic of China      122147  221 cm / 110 kg
# ...                            ...         ...              ...
# 145490           Republic of Korea      149217              NaN
# 145491                     Jamaica      149218              NaN
# 145492                        Cuba      149219              NaN
# 145493                         ROC      149220              NaN
# 145499                   Australia      149814              NaN
#
#                                              Affiliations Nick/petnames  \
# 89070   Shanghai Sharks, Shanghai (CHN) / Houston Rock...           NaN
# 5781                     NC State Wolfpack, Raleigh (USA)           NaN
# 6978    Žalgiris Kaunas, Kaunas (LTU) / Real Madrid, M...         Sabas
# 89075                       FC Barcelona, Barcelona (ESP)           NaN
# 120266                    Shanghai Sharks, Shanghai (CHN)           NaN
# ...                                                   ...           ...
# 145490                                                NaN           NaN
# 145491                                                NaN           NaN
# 145492                                                NaN           NaN
# 145493        SKIF Nizhny Novgorod, Nizhny Novgorod (RUS)           NaN
# 145499                                                NaN           NaN
#
#        Title(s)                                   Other names Nationality  \
# 89070       NaN                                           NaN         NaN
# 5781        NaN                                           NaN         NaN
# 6978        NaN  Arvidas Romas Sabonis, Арвидас Ромас Сабонис   Lithuania
# 89075       NaN                                           NaN         NaN
# 120266      NaN                                           NaN         NaN
# ...         ...                                           ...         ...
# 145490      NaN                                  Shin Ye-Chan         NaN
# 145491      NaN                                           NaN         NaN
# 145492      NaN                                           NaN         NaN
# 145493      NaN                                           NaN         NaN
# 145499      NaN                                           NaN         NaN
#
#                      Original name Name order                   name  \
# 89070                          姚•明   Oriental               Yao Ming
# 5781                           NaN        NaN         Tommy Burleson
# 6978                           NaN        NaN        Arvydas Sabonis
# 89075                          NaN        NaN         Roberto Dueñas
# 120266                        张•兆旭   Oriental           Zhang Zhaoxu
# ...                            ...        ...                    ...
# 145490                        신•예찬   Oriental            Sin Ye-Chan
# 145491                         NaN        NaN          Matthew Wepke
# 145492                         NaN        NaN  Carlos García-Ordóñez
# 145493  Ландыш Ильсуровна•Фаляхова        NaN     Landysh Falyakhova
# 145499                         NaN        NaN          Bill Phillips
#
#         height_cm  weight_kg
# 89070       226.0      141.0
# 5781        223.0      102.0
# 6978        223.0      122.0
# 89075       221.0      137.0
# 120266      221.0      110.0
# ...           ...        ...
# 145490        NaN        NaN
# 145491        NaN        NaN
# 145492        NaN        NaN
# 145493        NaN        NaN
# 145499        NaN        NaN
#
# [145500 rows x 19 columns]

# %%
# Parse out dates from 'Born' and 'Died' columns
date_pattern = r'(\d+ \w+ \d{4}|\d{4})'
df['born_date'] = df['Born'].str.extract(date_pattern)
df['born_year'] = df['Born'].str.extract(r'(\d{4})')

# %%
df
# Out:
#                                             Roles     Sex  \
# 0                       Competed in Olympic Games    Male
# 1                       Competed in Olympic Games    Male
# 2       Competed in Olympic Games • Administrator    Male
# 3                       Competed in Olympic Games    Male
# 4                       Competed in Olympic Games    Male
# ...                                           ...     ...
# 145495                  Competed in Olympic Games  Female
# 145496                  Competed in Olympic Games  Female
# 145497                  Competed in Olympic Games  Female
# 145498                  Competed in Olympic Games    Male
# 145499                Non-starter • Administrator    Male
#
#                                                 Full name  \
# 0       François Joseph Marie Antoine "Jean-François"•...
# 1                                 Arnaud Benjamin•Boetsch
# 2                             Jean Laurent Robert•Borotra
# 3                    Jacques Marie Stanislas Jean•Brugnon
# 4                                      Henry Albert•Canet
# ...                                                   ...
# 145495                                  Polina•Luchnikova
# 145496                     Valeriya Sergeyevna•Merkusheva
# 145497                                    Yuliya•Smirnova
# 145498                                     André•Foussard
# 145499                      William Berge "Bill"•Phillips
#
#                     Used name  \
# 0       Jean-François•Blanchy
# 1              Arnaud•Boetsch
# 2                Jean•Borotra
# 3             Jacques•Brugnon
# 4                Albert•Canet
# ...                       ...
# 145495      Polina•Luchnikova
# 145496    Valeriya•Merkusheva
# 145497        Yuliya•Smirnova
# 145498         André•Foussard
# 145499          Bill•Phillips
#
#                                                      Born  \
# 0             12 December 1886 in Bordeaux, Gironde (FRA)
# 1                  1 April 1969 in Meulan, Yvelines (FRA)
# 2       13 August 1898 in Biarritz, Pyrénées-Atlantiqu...
# 3                 11 May 1895 in Paris VIIIe, Paris (FRA)
# 4              17 April 1878 in Wandsworth, England (GBR)
# ...                                                   ...
# 145495         30 January 2002 in Serov, Sverdlovsk (RUS)
# 145496  20 September 1999 in Moskva (Moscow), Moskva (...
# 145497            8 May 1998 in Kotlas, Arkhangelsk (RUS)
# 145498            19 May 1899 in Niort, Deux-Sèvres (FRA)
# 145499  15 July 1913 in Dulwich Hill, New South Wales ...
#
#                                                      Died        NOC  \
# 0       2 October 1960 in Saint-Jean-de-Luz, Pyrénées-...     France
# 1                                                     NaN     France
# 2       17 July 1994 in Arbonne, Pyrénées-Atlantiques ...     France
# 3                   20 March 1978 in Monaco, Monaco (MON)     France
# 4                 25 July 1930 in Paris VIIe, Paris (FRA)     France
# ...                                                   ...        ...
# 145495                                                NaN        ROC
# 145496                                                NaN        ROC
# 145497                                                NaN        ROC
# 145498          18 March 1986 in Niort, Deux-Sèvres (FRA)     France
# 145499   20 October 2003 in Sydney, New South Wales (AUS)  Australia
#
#         athlete_id    Measurements  \
# 0                1             NaN
# 1                2  183 cm / 76 kg
# 2                3  183 cm / 76 kg
# 3                4  168 cm / 64 kg
# 4                5             NaN
# ...            ...             ...
# 145495      149222  167 cm / 61 kg
# 145496      149223  168 cm / 65 kg
# 145497      149224  163 cm / 55 kg
# 145498      149225          166 cm
# 145499      149814             NaN
#
#                                        Affiliations  ... Title(s) Other names  \
# 0                                               NaN  ...      NaN         NaN
# 1                Racing Club de France, Paris (FRA)  ...      NaN         NaN
# 2                                  TCP, Paris (FRA)  ...      NaN         NaN
# 3               Sporting club de Paris, Paris (FRA)  ...      NaN         NaN
# 4                                  TCP, Paris (FRA)  ...      NaN         NaN
# ...                                             ...  ...      ...         ...
# 145495                            Agidel, Ufa (RUS)  ...      NaN         NaN
# 145496  SKIF Nizhny Novgorod, Nizhny Novgorod (RUS)  ...      NaN         NaN
# 145497                            Agidel, Ufa (RUS)  ...      NaN         NaN
# 145498                  Beauvoisine FC, Rouen (FRA)  ...      NaN         NaN
# 145499                                          NaN  ...      NaN         NaN
#
#        Nationality                Original name Name order  \
# 0              NaN                          NaN        NaN
# 1              NaN                          NaN        NaN
# 2              NaN                          NaN        NaN
# 3              NaN                          NaN        NaN
# 4              NaN                          NaN        NaN
# ...            ...                          ...        ...
# 145495         NaN                          NaN        NaN
# 145496         NaN  Валерия Сергеевна•Меркушева        NaN
# 145497         NaN                Юлия•Смирнова        NaN
# 145498         NaN                          NaN        NaN
# 145499         NaN                          NaN        NaN
#
#                          name height_cm  weight_kg          born_date  \
# 0       Jean-François Blanchy       NaN        NaN   12 December 1886
# 1              Arnaud Boetsch     183.0       76.0       1 April 1969
# 2                Jean Borotra     183.0       76.0     13 August 1898
# 3             Jacques Brugnon     168.0       64.0        11 May 1895
# 4                Albert Canet       NaN        NaN      17 April 1878
# ...                       ...       ...        ...                ...
# 145495      Polina Luchnikova     167.0       61.0    30 January 2002
# 145496    Valeriya Merkusheva     168.0       65.0  20 September 1999
# 145497        Yuliya Smirnova     163.0       55.0         8 May 1998
# 145498         André Foussard     166.0        NaN        19 May 1899
# 145499          Bill Phillips       NaN        NaN       15 July 1913
#
#        born_year
# 0           1886
# 1           1969
# 2           1898
# 3           1895
# 4           1878
# ...          ...
# 145495      2002
# 145496      1999
# 145497      1998
# 145498      1899
# 145499      1913
#
# [145500 rows x 21 columns]

# %%
df[~df['Born'].str.match(date_pattern,na=False)]
# Out:
#                                                     Roles   Sex  \
# 12                              Competed in Olympic Games  Male
# 13                              Competed in Olympic Games  Male
# 27      Competed in Olympic Games • Competed in Olympi...  Male
# 28                              Competed in Olympic Games  Male
# 108                             Competed in Olympic Games  Male
# ...                                                   ...   ...
# 126484                          Competed in Olympic Games  Male
# 135275                          Competed in Olympic Games  Male
# 135280                          Competed in Olympic Games  Male
# 144129                          Competed in Olympic Games  Male
# 144132                          Competed in Olympic Games  Male
#
#                   Full name           Used name Born  \
# 12                J.•Defert           J.•Defert  NaN
# 13           Étienne•Durand      Étienne•Durand  NaN
# 27              Guy•Lejeune  Guy, Baron•Lejeune  NaN
# 28          Albert•Lippmann     Albert•Lippmann  NaN
# 108     Arthur B. J.•Norris       Arthur•Norris  NaN
# ...                     ...                 ...  ...
# 126484          Werner•Fehr         Werner•Fehr  NaN
# 135275          Aleko•Mulos         Aleko•Mulos  NaN
# 135280      Louis•Léstienne     Louis•Léstienne  NaN
# 144129       René•Van Damme      René•Van Damme  NaN
# 144132     Raphael•de Ligne    Raphael•de Ligne  NaN
#
#                                             Died            NOC  athlete_id  \
# 12                                           NaN         France          13
# 13                                           NaN         France          14
# 27                                           NaN         France          28
# 28                                           NaN         France          29
# 108                                          NaN  Great Britain         109
# ...                                          ...            ...         ...
# 126484  8 September 1943 in Zürich, Zürich (SUI)    Switzerland      128839
# 135275                                       NaN        Türkiye      138438
# 135280                                       NaN         France      138443
# 144129                                       NaN        Belgium      147802
# 144132                                       NaN        Belgium      147805
#
#        Measurements                          Affiliations  ... Title(s)  \
# 12              NaN    Racing Club de France, Paris (FRA)  ...      NaN
# 13              NaN                      TCP, Paris (FRA)  ...      NaN
# 27              NaN                                   NaN  ...    Baron
# 28              NaN                     unattached, (MIX)  ...      NaN
# 108             NaN            Queen's Club, London (GBR)  ...      NaN
# ...             ...                                   ...  ...      ...
# 126484          NaN        Grasshopper Club, Zürich (SUI)  ...      NaN
# 135275          NaN  Lycée de Galatasaray, İstanbul (TUR)  ...      Bey
# 135280          NaN        La Roubaisienne, Roubaix (FRA)  ...      NaN
# 144129          NaN                                   NaN  ...      NaN
# 144132          NaN                                   NaN  ...      NaN
#
#        Other names Nationality Original name Name order                name  \
# 12             NaN         NaN           NaN        NaN           J. Defert
# 13             NaN         NaN           NaN        NaN      Étienne Durand
# 27             NaN         NaN           NaN        NaN  Guy, Baron Lejeune
# 28             NaN         NaN           NaN        NaN     Albert Lippmann
# 108            NaN         NaN           NaN        NaN       Arthur Norris
# ...            ...         ...           ...        ...                 ...
# 126484         NaN         NaN           NaN        NaN         Werner Fehr
# 135275         NaN         NaN           NaN        NaN         Aleko Mulos
# 135280         NaN         NaN           NaN        NaN     Louis Léstienne
# 144129         NaN         NaN           NaN        NaN      René Van Damme
# 144132         NaN         NaN           NaN        NaN    Raphael de Ligne
#
#        height_cm  weight_kg  born_date born_year
# 12           NaN        NaN        NaN       NaN
# 13           NaN        NaN        NaN       NaN
# 27           NaN        NaN        NaN       NaN
# 28           NaN        NaN        NaN       NaN
# 108          NaN        NaN        NaN       NaN
# ...          ...        ...        ...       ...
# 126484       NaN        NaN        NaN       NaN
# 135275       NaN        NaN        NaN       NaN
# 135280       NaN        NaN        NaN       NaN
# 144129       NaN        NaN        NaN       NaN
# 144132       NaN        NaN        NaN       NaN
#
# [1936 rows x 21 columns]

# %%
df[~df['Born'].str.match(date_pattern,na=False) & df['Born'].notna()]
# Out:
#                             Roles     Sex               Full name  \
# 1251    Competed in Olympic Games    Male    Eduardo•Cornejo Díaz
# 1277    Competed in Olympic Games    Male  Manuel•Videla Castillo
# 1794    Competed in Olympic Games    Male   Luis•Castillo Sánchez
# 1800    Competed in Olympic Games    Male   Lincoln•Salcedo Reina
# 1805    Competed in Olympic Games    Male    Gharib Ibrahim•Afifi
# ...                           ...     ...                     ...
# 86829   Competed in Olympic Games    Male           Charles•Jenny
# 100003  Competed in Olympic Games    Male         Gora Chand•Seal
# 101533  Competed in Olympic Games    Male       David Hey•Bratton
# 101534  Competed in Olympic Games    Male         David A.•Hesser
# 116330  Competed in Olympic Games  Female            Cha•Yong-Hwa
#
#               Used name                                      Born  \
# 1251    Eduardo•Cornejo                                 (c. 1929)
# 1277      Manuel•Videla                              (circa 1920)
# 1794      Luis•Castillo                in Guayaquil, Guayas (ECU)
# 1800    Lincoln•Salcedo                in Guayaquil, Guayas (ECU)
# 1805       Gharib•Afifi     in Al-Qahira (Cairo), Al-Qahira (EGY)
# ...                 ...                                       ...
# 86829     Charles•Jenny    April 1897 in Basel, Basel-Stadt (SUI)
# 100003        Gora•Seal                              January 1923
# 101533    David•Bratton  October 1869 in New York, New York (USA)
# 101534     David•Hesser         January 1884 in ?, New York (USA)
# 116330     Cha•Yong-Hwa           in Pyeongyang, Pyeongyang (PRK)
#
#                                                      Died  \
# 1251    23 November 1998 in Santiago, Santiago Metropo...
# 1277                                                  NaN
# 1794                                                  NaN
# 1800                                                  NaN
# 1805                                       (In the 1990s)
# ...                                                   ...
# 86829                                                 NaN
# 100003  23 September 2017 in Kolkata (Calcutta), West ...
# 101533         3 December 1904 in Chicago, Illinois (USA)
# 101534  13 February 1908 in Manhattan, New York, New Y...
# 116330                                                NaN
#
#                                           NOC  athlete_id    Measurements  \
# 1251                                    Chile        1258             NaN
# 1277                                    Chile        1284             NaN
# 1794                                  Ecuador        1801             NaN
# 1800                                  Ecuador        1807             NaN
# 1805                                    Egypt        1812             NaN
# ...                                       ...         ...             ...
# 86829                             Switzerland       87523          178 cm
# 100003                                  India      100829             NaN
# 101533                          United States      102423             NaN
# 101534                          United States      102424             NaN
# 116330  Democratic People's Republic of Korea      117719  145 cm / 39 kg
#
#                                 Affiliations  ... Title(s) Other names  \
# 1251                                     NaN  ...      NaN         NaN
# 1277                                     NaN  ...      NaN         NaN
# 1794                                     NaN  ...      NaN         NaN
# 1800                                     NaN  ...      NaN         NaN
# 1805         El-Olympi, Al-Iskanderiya (EGY)  ...      NaN         NaN
# ...                                      ...  ...      ...         ...
# 86829                                    NaN  ...      NaN         NaN
# 100003  Central Swimming Club, Kolkata (IND)  ...      NaN         NaN
# 101533                  NYAC, New York (USA)  ...      NaN         NaN
# 101534                  NYAC, New York (USA)  ...      NaN         NaN
# 116330                 Pyongyang Sports Club  ...      NaN         NaN
#
#        Nationality       Original name Name order             name height_cm  \
# 1251           NaN                 NaN        NaN  Eduardo Cornejo       NaN
# 1277           NaN                 NaN        NaN    Manuel Videla       NaN
# 1794           NaN                 NaN        NaN    Luis Castillo       NaN
# 1800           NaN                 NaN        NaN  Lincoln Salcedo       NaN
# 1805           NaN  غريب ابراهيم•عفيفي        NaN     Gharib Afifi       NaN
# ...            ...                 ...        ...              ...       ...
# 86829          NaN                 NaN        NaN    Charles Jenny     178.0
# 100003         NaN                 NaN        NaN        Gora Seal       NaN
# 101533         NaN                 NaN        NaN    David Bratton       NaN
# 101534         NaN                 NaN        NaN     David Hesser       NaN
# 116330         NaN                 NaN   Oriental     Cha Yong-Hwa     145.0
#
#         weight_kg  born_date born_year
# 1251          NaN       1929      1929
# 1277          NaN       1920      1920
# 1794          NaN        NaN       NaN
# 1800          NaN        NaN       NaN
# 1805          NaN        NaN       NaN
# ...           ...        ...       ...
# 86829         NaN       1897      1897
# 100003        NaN       1923      1923
# 101533        NaN       1869      1869
# 101534        NaN       1884      1884
# 116330       39.0        NaN       NaN
#
# [208 rows x 21 columns]

# %%
# testing with small data testcases
small_data = pd.DataFrame(['1895 in Scotland', '12 December 1900 in Boston'], columns=['Born'])

date_pattern = r'(\d+ \w+ \d{4}|\d{4})'
small_data['born_date'] = df['Born'].str.extract(date_pattern)

small_data
# Out:
#                          Born         born_date
# 0            1895 in Scotland  12 December 1886
# 1  12 December 1900 in Boston      1 April 1969

# %%
df['born_date'] = pd.to_datetime(df['born_date'], format="mixed", errors='coerce')
df['born_year'] = pd.to_numeric(df['born_year'])

# %%
 
df['died_date'] = df['Died'].str.extract(date_pattern)
df['died_date'] = pd.to_datetime(df['died_date'], format="mixed", errors='coerce')

# %%
# Get city, region, and country from Born column
location_pattern = r'in ([\w\s()-]+), ([\w\s-]+) \((\w+)\)'
df['Born'].str.extract(location_pattern)
# Out:
#                       0                     1    2
# 0              Bordeaux               Gironde  FRA
# 1                Meulan              Yvelines  FRA
# 2              Biarritz  Pyrénées-Atlantiques  FRA
# 3           Paris VIIIe                 Paris  FRA
# 4            Wandsworth               England  GBR
# ...                 ...                   ...  ...
# 145495            Serov            Sverdlovsk  RUS
# 145496  Moskva (Moscow)                Moskva  RUS
# 145497           Kotlas           Arkhangelsk  RUS
# 145498            Niort           Deux-Sèvres  FRA
# 145499     Dulwich Hill       New South Wales  AUS
#
# [145500 rows x 3 columns]

# %%
df[['born_city','born_region','born_country']] = df['Born'].str.extract(location_pattern, expand=True)

# %%
import pandas as pd
pd.set_option('display.max_colwidth', None)

df.value_counts('born_city',ascending=False).head(25)
# Out:
# born_city
# Budapest                          1378
# Moskva (Moscow)                    883
# Oslo                               708
# Stockholm                          629
# Praha (Prague)                     600
# Toronto                            579
# Wien (Vienna)                      547
# Buenos Aires                       538
# København (Copenhagen)             523
# Sydney                             497
# Montréal                           468
# Berlin                             467
# Ciudad de México (Mexico City)     455
# Helsinki                           439
# Rio de Janeiro                     433
# Amsterdam                          429
# Barcelona                          425
# Melbourne                          417
# New York                           416
# Seoul                              405
# São Paulo                          393
# London                             386
# Madrid                             379
# Athina (Athens)                    348
# Roma                               344
# Name: count, dtype: int64

# %%
# Remove any unneccessary columns
df.columns
# Out:
# Index(['Roles', 'Sex', 'Full name', 'Used name', 'Born', 'Died', 'NOC',
#        'athlete_id', 'Measurements', 'Affiliations', 'Nick/petnames',
#        'Title(s)', 'Other names', 'Nationality', 'Original name', 'Name order',
#        'name', 'height_cm', 'weight_kg', 'born_date', 'born_year', 'died_date',
#        'born_city', 'born_region', 'born_country'],
#       dtype='object')

# %%
columns_to_keep = ['athlete_id', 'name', 'born_date', 'born_city', 'born_region',
                   'born_country', 'NOC', 'height_cm', 'weight_kg', 'died_date']

df_clean = df[columns_to_keep]

# %%
df_clean.to_csv('./clean-data/bios.csv', index=False)

# %% [markdown]
# ## Cleaning results data

# %%
import pandas as pd

results = pd.read_csv('results/results.csv')
# Out:
# /tmp/ipykernel_469441/2293983339.py:3: DtypeWarning: Columns (9) have mixed types. Specify dtype option on import or set low_memory=False.
#   results = pd.read_csv('results/results.csv')

# %%
df = results.copy()

# %%
df.head()
# Out:
#                   Games                     Event             Team  Pos Medal  \
# 0  1912 Summer Olympics    Singles, Men (Olympic)              NaN  =17   NaN
# 1  1912 Summer Olympics    Doubles, Men (Olympic)   Jean Montariol  DNS   NaN
# 2  1920 Summer Olympics    Singles, Men (Olympic)              NaN  =32   NaN
# 3  1920 Summer Olympics  Doubles, Mixed (Olympic)  Jeanne Vaussard   =8   NaN
# 4  1920 Summer Olympics    Doubles, Men (Olympic)  Jacques Brugnon    4   NaN
#
#                       As  athlete_id  NOC Discipline Nationality  Unnamed: 7
# 0  Jean-François Blanchy           1  FRA     Tennis         NaN         NaN
# 1  Jean-François Blanchy           1  FRA     Tennis         NaN         NaN
# 2  Jean-François Blanchy           1  FRA     Tennis         NaN         NaN
# 3  Jean-François Blanchy           1  FRA     Tennis         NaN         NaN
# 4  Jean-François Blanchy           1  FRA     Tennis         NaN         NaN

# %% [markdown]
# ### Cleaning to-do:
# - [x] Split year and type from games
# - [x] split out tied column from position
# - [x] make non-numeric POSs NAN in Pos
# - [x] drop unnamed column
# - [x] Reorder columns

# %%
df['place'] = df['Pos'].str.extract(r'(\d+)')
df['tied'] = df['Pos'].str.contains("=")

# %%
df['medal_new'] = df["Medal"].map({"Bronze": 3, "Silver": 2, "Gold": 1})

# %%
df[['year', 'type']] = df['Games'].str.extract(r'(\d{4}) (Summer|Winter)', expand=True)

# %%
df.head()
# Out:
#                   Games                     Event             Team  Pos Medal  \
# 0  1912 Summer Olympics    Singles, Men (Olympic)              NaN  =17   NaN
# 1  1912 Summer Olympics    Doubles, Men (Olympic)   Jean Montariol  DNS   NaN
# 2  1920 Summer Olympics    Singles, Men (Olympic)              NaN  =32   NaN
# 3  1920 Summer Olympics  Doubles, Mixed (Olympic)  Jeanne Vaussard   =8   NaN
# 4  1920 Summer Olympics    Doubles, Men (Olympic)  Jacques Brugnon    4   NaN
#
#                       As  athlete_id  NOC Discipline Nationality  Unnamed: 7  \
# 0  Jean-François Blanchy           1  FRA     Tennis         NaN         NaN
# 1  Jean-François Blanchy           1  FRA     Tennis         NaN         NaN
# 2  Jean-François Blanchy           1  FRA     Tennis         NaN         NaN
# 3  Jean-François Blanchy           1  FRA     Tennis         NaN         NaN
# 4  Jean-François Blanchy           1  FRA     Tennis         NaN         NaN
#
#   place   tied  medal_new  year    type
# 0    17   True        NaN  1912  Summer
# 1   NaN  False        NaN  1912  Summer
# 2    32   True        NaN  1920  Summer
# 3     8   True        NaN  1920  Summer
# 4     4  False        NaN  1920  Summer

# %%
df['year'] = pd.to_numeric(df['year'])

# %%
df.sort_values('year', ascending=False)
# Out:
#                           Games                             Event      Team  \
# 308407     2022 Winter Olympics           Slalom, Women (Olympic)       NaN
# 274176     2022 Winter Olympics         Ice Hockey, Men (Olympic)    Latvia
# 274171     2022 Winter Olympics         Ice Hockey, Men (Olympic)    Latvia
# 274168     2022 Winter Olympics         Ice Hockey, Men (Olympic)    Latvia
# 274149     2022 Winter Olympics              Four, Open (Olympic)  Latvia 1
# ...                         ...                               ...       ...
# 203177  1906 Intercalated Games  Sabre, Individual, Men (Olympic)       NaN
# 203178  1906 Intercalated Games        Sabre, Team, Men (Olympic)   Hungary
# 217586  1906 Intercalated Games      Football, Men (Intercalated)    Athens
# 217587  1906 Intercalated Games      Football, Men (Intercalated)    Athens
# 271490  1906 Intercalated Games      Platform, Men (Intercalated)       NaN
#
#          Pos Medal                    As  athlete_id  NOC  \
# 308407  24.0   NaN  Charlotta Säfvenberg      148986  NaN
# 274176  11.0   NaN        Ronalds Ķēniņš      128130  LAT
# 274171   DNS   NaN   Kristers Gudļevskis      128127  LAT
# 274168    11   NaN       Ralfs Freibergs      128125  LAT
# 274149   5.0   NaN     Oskars Ķibermanis      128118  LAT
# ...      ...   ...                   ...         ...  ...
# 203177     5   NaN       Lóránt Mészáros       95189  HUN
# 203178     4   NaN       Lóránt Mészáros       95189  HUN
# 217586    AC   NaN       Georgios Pantos      100811  GRE
# 217587    AC   NaN  Alexandros Kalafatis      100812  GRE
# 271490  13.0   NaN      Wilhelm Lindgren      127259  SWE
#
#                      Discipline Nationality  Unnamed: 7 place   tied  \
# 308407                      NaN         NaN         NaN    24  False
# 274176  Ice Hockey (Ice Hockey)         NaN         NaN    11  False
# 274171  Ice Hockey (Ice Hockey)         NaN         NaN   NaN  False
# 274168  Ice Hockey (Ice Hockey)         NaN         NaN    11  False
# 274149    Bobsleigh (Bobsleigh)         NaN         NaN     5  False
# ...                         ...         ...         ...   ...    ...
# 203177                  Fencing         NaN         NaN     5  False
# 203178                  Fencing         NaN         NaN     4  False
# 217586      Football (Football)         NaN         NaN   NaN  False
# 217587      Football (Football)         NaN         NaN   NaN  False
# 271490        Diving (Aquatics)         NaN         NaN    13  False
#
#         medal_new    year    type
# 308407        NaN  2022.0  Winter
# 274176        NaN  2022.0  Winter
# 274171        NaN  2022.0  Winter
# 274168        NaN  2022.0  Winter
# 274149        NaN  2022.0  Winter
# ...           ...     ...     ...
# 203177        NaN     NaN     NaN
# 203178        NaN     NaN     NaN
# 217586        NaN     NaN     NaN
# 217587        NaN     NaN     NaN
# 271490        NaN     NaN     NaN
#
# [308408 rows x 16 columns]

# %%
df.columns
# Out:
# Index(['Games', 'Event', 'Team', 'Pos', 'Medal', 'As', 'athlete_id', 'NOC',
#        'Discipline', 'Nationality', 'Unnamed: 7', 'place', 'tied', 'medal_new',
#        'year', 'type'],
#       dtype='object')

# %%
columns_to_keep = ['year','type','Discipline', 'Event', 'As', 'athlete_id', 'NOC', 'Team', 'place', 'tied', 'Medal']
df = df[columns_to_keep]

# %%
import janitor

# %%
df = df.clean_names()

# %%
df.to_csv('./clean-data/results.csv', index=False)

# %%
df['place'] = pd.to_numeric(df['place'])

# %%
df['tied'] = df['tied'].astype(bool)

# %%
df.head()
# Out:
#      year    type discipline                     event                     as  \
# 0  1912.0  Summer     Tennis    Singles, Men (Olympic)  Jean-François Blanchy
# 1  1912.0  Summer     Tennis    Doubles, Men (Olympic)  Jean-François Blanchy
# 2  1920.0  Summer     Tennis    Singles, Men (Olympic)  Jean-François Blanchy
# 3  1920.0  Summer     Tennis  Doubles, Mixed (Olympic)  Jean-François Blanchy
# 4  1920.0  Summer     Tennis    Doubles, Men (Olympic)  Jean-François Blanchy
#
#    athlete_id  noc             team  place   tied medal
# 0           1  FRA              NaN   17.0   True   NaN
# 1           1  FRA   Jean Montariol    NaN  False   NaN
# 2           1  FRA              NaN   32.0   True   NaN
# 3           1  FRA  Jeanne Vaussard    8.0   True   NaN
# 4           1  FRA  Jacques Brugnon    4.0  False   NaN

# %%
df.to_csv('./clean-data/results.csv',index=False)

# %%
df = pd.read_csv('clean-data/bios.csv')

# %%
df
# Out:
#         athlete_id                   name   born_date        born_city  \
# 0                1  Jean-François Blanchy  1886-12-12         Bordeaux
# 1                2         Arnaud Boetsch  1969-04-01           Meulan
# 2                3           Jean Borotra  1898-08-13         Biarritz
# 3                4        Jacques Brugnon  1895-05-11      Paris VIIIe
# 4                5           Albert Canet  1878-04-17       Wandsworth
# ...            ...                    ...         ...              ...
# 145495      149222      Polina Luchnikova  2002-01-30            Serov
# 145496      149223    Valeriya Merkusheva  1999-09-20  Moskva (Moscow)
# 145497      149224        Yuliya Smirnova  1998-05-08           Kotlas
# 145498      149225         André Foussard  1899-05-19            Niort
# 145499      149814          Bill Phillips  1913-07-15     Dulwich Hill
#
#                  born_region born_country        NOC  height_cm  weight_kg  \
# 0                    Gironde          FRA     France        NaN        NaN
# 1                   Yvelines          FRA     France      183.0       76.0
# 2       Pyrénées-Atlantiques          FRA     France      183.0       76.0
# 3                      Paris          FRA     France      168.0       64.0
# 4                    England          GBR     France        NaN        NaN
# ...                      ...          ...        ...        ...        ...
# 145495            Sverdlovsk          RUS        ROC      167.0       61.0
# 145496                Moskva          RUS        ROC      168.0       65.0
# 145497           Arkhangelsk          RUS        ROC      163.0       55.0
# 145498           Deux-Sèvres          FRA     France      166.0        NaN
# 145499       New South Wales          AUS  Australia        NaN        NaN
#
#          died_date
# 0       1960-10-02
# 1              NaN
# 2       1994-07-17
# 3       1978-03-20
# 4       1930-07-25
# ...            ...
# 145495         NaN
# 145496         NaN
# 145497         NaN
# 145498  1986-03-18
# 145499  2003-10-20
#
# [145500 rows x 10 columns]
